# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna172/Python/blob/master/%D0%A6%D0%B2%D0%B5%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='ticks', palette=sns.cubehelix_palette(8))

# %%
#ссылки:
# поиск нужного цвета: https://colorbrewer2.org/#type=sequential&scheme=YlGnBu&n=9
# инфа по тому, как работать с цветами: https://seaborn.pydata.org/tutorial/color_palettes.html#palette-tutorial
# гит инфа: https://gist.github.com/mwaskom/b35f6ebc2d4b340b4f64a4e28e778486
# названия сетов цветов: https://matplotlib.org/tutorials/colors/colormaps.html

# %%
obs_ts = pd.read_csv("FRB_H10.csv", parse_dates=['date'], na_values='ND')

# %%
obs_ts.plot('date', 'rate');

# %%
sns.palplot(sns.color_palette("Set2"))

# %%
flatui = ["#41b6c4", "#9ecae1", "#f768a1", "#c994c7", "#8c6bb1", "#41b6c4", "#c994c7", "#980043", "#fa9fb5", "#99d8c9", "#3498db", "#e74c3c"]

sns.set(style='ticks', palette=sns.color_palette(flatui))

# %%
obs_ts.plot('date', 'rate');

# %%
sns.set(style='ticks', palette=sns.diverging_palette(-91, 220, sep=20, n=7,))
# Pastel2
# Paired
# sns.diverging_palette(220, 20, sep=20, as_cmap=True) просто менять цифры задающие цвета, но они олжны быть целыми
# PiYG

# %%
obs_ts.plot('date', 'rate');
